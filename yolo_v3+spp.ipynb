# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15851, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 15851 (delta 5), reused 12 (delta 4), pack-reused 15833
# Receiving objects: 100% (15851/15851), 14.38 MiB | 1.86 MiB/s, done.
# Resolving deltas: 100% (10675/10675), done.

# %%
# %cd /content/gdrive/MyDrive/YOLO_Detection_V3
# Out:
# /content/gdrive/MyDrive/YOLO_Detection_V3

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# fatal: destination path 'darknet' already exists and is not an empty directory.

# %%
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive/YOLO_Detection
# Out:
# ln: failed to create symbolic link '/mydrive/My Drive': File exists
# darknet		   train_set.data   train_set.zip  yolov3-no-modification.cfg.gdoc
# generate_train.py  train_set.names  yolo_v3.ipynb

# %%
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=0/' Makefile
# !sed -i 's/OPENMP=0/OPENMP=1/' Makefile
# !sed -i 's/LIBSO=0/LIBSO=1/' Makefile
# !make
# Out:
# /content/gdrive/MyDrive/YOLO_Detection_V3/darknet
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -fopenmp -DGPU -DCUDNN -I/usr/local/cudnn/include -fPIC -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:945:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#   945 |                 float rgb[3];
#       |                       ^~~
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1443:14: warning: unused variable ‘buff’ [-Wunused-variable]
#  1443 |         char buff[100];
# ...

# %%
# !ls /mydrive/YOLO_Detection
# Out:
# darknet		   train_set.data   train_set.zip  yolov3-no-modification.cfg.gdoc
# generate_train.py  train_set.names  yolo_v3.ipynb

# %%
# !cp /mydrive/YOLO_Detection/train_set.zip ../

# %%
# !unzip ../train_set.zip -d data/
# Out:
# Archive:  ../train_set.zip
#   inflating: data/train_set/cju0qkwl35piu0993l0dewei2.jpg
#   inflating: data/train_set/cju0qkwl35piu0993l0dewei2.txt
#   inflating: data/train_set/cju0qoxqj9q6s0835b43399p4.jpg
#   inflating: data/train_set/cju0qoxqj9q6s0835b43399p4.txt
#   inflating: data/train_set/cju0qx73cjw570799j4n5cjze.jpg
#   inflating: data/train_set/cju0qx73cjw570799j4n5cjze.txt
#   inflating: data/train_set/cju0roawvklrq0799vmjorwfv.jpg
#   inflating: data/train_set/cju0roawvklrq0799vmjorwfv.txt
#   inflating: data/train_set/cju0rx1idathl0835detmsp84.jpg
#   inflating: data/train_set/cju0rx1idathl0835detmsp84.txt
#   inflating: data/train_set/cju0s2a9ekvms080138tjjpxr.jpg
#   inflating: data/train_set/cju0s2a9ekvms080138tjjpxr.txt
#   inflating: data/train_set/cju0s690hkp960855tjuaqvv0.jpg
#   inflating: data/train_set/cju0s690hkp960855tjuaqvv0.txt
#   inflating: data/train_set/cju0sr5ghl0nd08789uzf1raf.jpg
#   inflating: data/train_set/cju0sr5ghl0nd08789uzf1raf.txt
# ...

# %%
import glob
images_list = glob.glob("data/train_set/*.jpg")
print(images_list)
# Out:
# ['data/train_set/cju0qkwl35piu0993l0dewei2.jpg', 'data/train_set/cju0qoxqj9q6s0835b43399p4.jpg', 'data/train_set/cju0qx73cjw570799j4n5cjze.jpg', 'data/train_set/cju0roawvklrq0799vmjorwfv.jpg', 'data/train_set/cju0rx1idathl0835detmsp84.jpg', 'data/train_set/cju0s2a9ekvms080138tjjpxr.jpg', 'data/train_set/cju0s690hkp960855tjuaqvv0.jpg', 'data/train_set/cju0sr5ghl0nd08789uzf1raf.jpg', 'data/train_set/cju0sxqiclckk08551ycbwhno.jpg', 'data/train_set/cju0t4oil7vzk099370nun5h9.jpg', 'data/train_set/cju0u2g7pmnux0801vkk47ivj.jpg', 'data/train_set/cju0u82z3cuma0835wlxrnrjv.jpg', 'data/train_set/cju0ue769mxii08019zqgdbxn.jpg', 'data/train_set/cju0vtox5ain6099360pu62rp.jpg', 'data/train_set/cju13cgqmnhwn0988yrainhcp.jpg', 'data/train_set/cju13fwthn9mq0835gacxgy01.jpg', 'data/train_set/cju13hp5rnbjx0835bf0jowgx.jpg', 'data/train_set/cju14g8o4xui30878gkgbrvqj.jpg', 'data/train_set/cju14hjh2ob2o0835ouz3r5aa.jpg', 'data/train_set/cju14pxbaoksp0835qzorx6g6.jpg', 'data/train_set/cju15czxqp3lv0835jvhg
# ...

# %%
file = open("data/train.txt", "w")
file.write("\n".join(images_list))
file.close()

# %%
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# use this to upload files
def upload():
  from google.colab import files
  uploaded = files.upload()
  for name, data in uploaded.items():
    with open(name, 'wb') as f:
      f.write(data)
      print ('saved file', name)

# use this to download a file
def download(path):
  from google.colab import files
  files.download(path)

# %%
# %cd ./darknet
# Out:
# /content/gdrive/MyDrive/YOLO_Detection/darknet

# %%
# !./darknet detector test /content/gdrive/MyDrive/YOLO_Detection_V3/darknet/data/train_set.data /content/gdrive/MyDrive/YOLO_Detection_V3/darknet/cfg/yolov3-spp-training.cfg /content/gdrive/MyDrive/YOLO_Detection_V3/darknet/backup/yolov3-spp-training_final.weights /content/gdrive/MyDrive/YOLO_Detection_V3/darknet/data/cju2ysg748ru80878sp6j0gm0.jpg -thresh 0.3
imShow('predictions.jpg')
# Out:
# /bin/bash: line 1: ./darknet: No such file or directory
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ccc8c1f63128> in <cell line: 2>()
#       1 get_ipython().system('./darknet detector test /content/gdrive/MyDrive/YOLO_Detection_V3/darknet/data/train_set.data /content/gdrive/MyDrive/YOLO_Detection_V3/darknet/cfg/yolov3-spp-training.cfg /content/gdrive/MyDrive/YOLO_Detection_V3/darknet/backup/yolov3-spp-training_final.weights /content/gdrive/MyDrive/YOLO_Detection_V3/darknet/data/cju2ysg748ru80878sp6j0gm0.jpg -thresh 0.3')
# ----> 2 imShow('predictions.jpg')
#
# NameError: name 'imShow' is not defined
